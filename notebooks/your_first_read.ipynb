# %%
# import the pymongo library - this is the Python driver!
import pymongo

# replace "uri" with your Atlas URI string - should look like mongodb+srv://...
uri = "mongodb+srv://infarctus05:simplon95870@cluster0.ef8pe3y.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
mflix = client.sample_mflix

# movies is our collection handle - it refers to the sample_mflix.movies collection
movies = mflix.movies
# Out:
# ---------------------------------------------------------------------------
# LifetimeTimeout                           Traceback (most recent call last)
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\srv_resolver.py:89, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      88 try:
# ---> 89     results = _resolve(
#      90         "_" + self.__srv + "._tcp." + self.__fqdn, "SRV", lifetime=self.__connect_timeout
#      91     )
#      92 except Exception as exc:
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\srv_resolver.py:43, in _resolve(*args, **kwargs)
#      41 if hasattr(resolver, "resolve"):
#      42     # dnspython >= 2
# ---> 43     return resolver.resolve(*args, **kwargs)
#      44 # dnspython 1.X
#
# File ~\anaconda3\envs\new\lib\site-packages\dns\resolver.py:1193, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1184 """Query nameservers to find the answer to the question.
#    1185
#    1186 This is a convenience function that uses the default resolver
#    (...)
#    1190 parameters.
#    1191 """
# -> 1193 return get_default_resolver().resolve(qname, rdtype, rdclass, tcp, source,
#    1194                                       raise_on_no_answer, source_port,
#    1195                                       lifetime, search)
#
# File ~\anaconda3\envs\new\lib\site-packages\dns\resolver.py:1066, in Resolver.resolve(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1065     time.sleep(backoff)
# -> 1066 timeout = self._compute_timeout(start, lifetime,
#    1067                                 resolution.errors)
#    1068 try:
#
# File ~\anaconda3\envs\new\lib\site-packages\dns\resolver.py:879, in BaseResolver._compute_timeout(self, start, lifetime, errors)
#     878 if duration >= lifetime:
# --> 879     raise LifetimeTimeout(timeout=duration, errors=errors)
#     880 return min(lifetime - duration, self.timeout)
#
# LifetimeTimeout: The resolution lifetime expired after 21.607 seconds: Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 83.142.144.246 UDP port 53 answered [WinError 10054] Une connexion existante a dû être fermée par l’hôte distant; Server 83.142.144.249 UDP port 53 answered [WinError 10054] Une connexion existante a dû être fermée par l’hôte distant; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConfigurationError                        Traceback (most recent call last)
# Input In [33], in <cell line: 6>()
#       4 # replace "uri" with your Atlas URI string - should look like mongodb+srv://...
#       5 uri = "mongodb+srv://infarctus05:simplon95870@cluster0.ef8pe3y.mongodb.net/?retryWrites=true&w=majority"
# ----> 6 client = pymongo.MongoClient(uri)
#       7 mflix = client.sample_mflix
#       9 # movies is our collection handle - it refers to the sample_mflix.movies collection
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\mongo_client.py:736, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     732 if timeout is not None:
#     733     timeout = common.validate_timeout_or_none_or_zero(
#     734         keyword_opts.cased_key("connecttimeoutms"), timeout
#     735     )
# --> 736 res = uri_parser.parse_uri(
#     737     entity,
#     738     port,
#     739     validate=True,
#     740     warn=True,
#     741     normalize=False,
#     742     connect_timeout=timeout,
#     743     srv_service_name=srv_service_name,
#     744     srv_max_hosts=srv_max_hosts,
#     745 )
#     746 seeds.update(res["nodelist"])
#     747 username = res["username"] or username
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\uri_parser.py:542, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     540 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     541 dns_resolver = _SrvResolver(fqdn, connect_timeout, srv_service_name, srv_max_hosts)
# --> 542 nodes = dns_resolver.get_hosts()
#     543 dns_options = dns_resolver.get_options()
#     544 if dns_options:
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\srv_resolver.py:121, in _SrvResolver.get_hosts(self)
#     120 def get_hosts(self):
# --> 121     _, nodes = self._get_srv_response_and_hosts(True)
#     122     return nodes
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\srv_resolver.py:101, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#     100 def _get_srv_response_and_hosts(self, encapsulate_errors):
# --> 101     results = self._resolve_uri(encapsulate_errors)
#     103     # Construct address tuples
#     104     nodes = [
#     105         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port) for res in results
#     106     ]
#
# File ~\anaconda3\envs\new\lib\site-packages\pymongo\srv_resolver.py:97, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      95         raise
#      96     # Else, raise all errors as ConfigurationError.
# ---> 97     raise ConfigurationError(str(exc))
#      98 return results
#
# ConfigurationError: The resolution lifetime expired after 21.607 seconds: Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 83.142.144.246 UDP port 53 answered [WinError 10054] Une connexion existante a dû être fermée par l’hôte distant; Server 83.142.144.249 UDP port 53 answered [WinError 10054] Une connexion existante a dû être fermée par l’hôte distant; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.; Server 192.168.3.2 UDP port 53 answered The DNS operation timed out.; Server 100.120.19.1 UDP port 53 answered The DNS operation timed out.

# %%
# find one document in the "movies" collection - does not matter which one
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 0,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
#  'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5},
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32},
#   'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}

# %%
movies.users.create_index([("email", 1), ("password", 1)], unique=True)
# Out:
# 'email_1_password_1'

# %%
countries = ['Kosovo', 'Japan']
#movies.find({'countries' :{ '$in': ['USA']}}, {'title'}, {'_id'})
list(movies.find({"countries": {"$in": countries}}, {"title": 1, "_id": 1}))
# Out:
# [{'_id': ObjectId('573a1392f29313caabcd9d4f'), 'title': 'I Was Born, But...'},
#  {'_id': ObjectId('573a1392f29313caabcd9e7c'), 'title': 'Dekigokoro'},
#  {'_id': ObjectId('573a1392f29313caabcda641'),
#   'title': 'A Story of Floating Weeds'},
#  {'_id': ObjectId('573a1392f29313caabcdab08'),
#   'title': 'Wife! Be Like a Rose!'},
#  {'_id': ObjectId('573a1392f29313caabcdad0d'), 'title': 'Sisters of the Gion'},
#  {'_id': ObjectId('573a1392f29313caabcdb29d'),
#   'title': 'Children in the Wind'},
#  {'_id': ObjectId('573a1393f29313caabcdbe87'), 'title': 'Zangiku monogatari'},
#  {'_id': ObjectId('573a1393f29313caabcdc6f0'),
#   'title': 'The Brothers and Sisters of the Toda Family'},
#  {'_id': ObjectId('573a1393f29313caabcdd8af'),
#   'title': 'Morning for the Osone Family'},
#  {'_id': ObjectId('573a1393f29313caabcdd9da'),
#   'title': 'The Ball at the Anjo House'},
#  {'_id': ObjectId('573a1393f29313caabcddca8'),
#   'title': 'One Wonderful Sunday'},
#  {'_id': ObjectId('573a1393f29313caabcddf2b'), 'title': 'A Hen in the Wind'},
#  {'_id': ObjectId('573a1393f29313caabcde0fa'), 'title': 'Drunken Angel'},
#  {'_id': ObjectId('573a1393f29313caabcde107'), 'title': 'Yoru no onnatachi'},
#  {'_id': ObjectId('573a1393f29313caabcde1a0'), 'title': 'Late Spring'},
#  {'_id': ObjectId('573a1393f29313caabcde3cb'), 'title': 'Stray Dog'},
#  {'_id': ObjectId('573a1393f29313caabcde47a'), 'title': 'The Quiet Duel'},
#  {'_id': ObjectId('573a1394f29313caabcde7f9'),
#   'title': 'The Munekata Sisters'},
#  {'_id': ObjectId('573a1394f29313caabcde86b'), 'title': 'Rashomon'},
#  {'_id': ObjectId('573a1394f29313caabcdea0a'), 'title': 'Early Summer'},
#  {'_id': ObjectId('573a1394f29313caabcdeb9f'), 'title': 'Carmen Comes Home'},
#  {'_id': ObjectId('573a1394f29313caabcdebf9'), 'title': 'Repast'},
#  {'_id': ObjectId('573a1394f29313caabcdeeb7'),
#   'title': 'Children of Hiroshima'},
#  {'_id': ObjectId('573a1394f29313caabcdef98'), 'title': 'Ikiru'},
#  {'_id': ObjectId('573a1394f29313caabcdf093'),
#   'title': 'Flavor of Green Tea Over Rice'},
#  {'_id': ObjectId('573a1394f29313caabcdf113'), 'title': 'The Life of Oharu'},
#  {'_id': ObjectId('573a1394f29313caabcdf44f'), 'title': 'Gate of Hell'},
#  {'_id': ObjectId('573a1394f29313caabcdf63c'), 'title': 'Tokyo Story'},
#  {'_id': ObjectId('573a1394f29313caabcdf64f'), 'title': 'Wife'},
#  {'_id': ObjectId('573a1394f29313caabcdf65b'), 'title': 'Ugetsu'},
#  {'_id': ObjectId('573a1394f29313caabcdf757'), 'title': 'Ana-ta-han'},
#  {'_id': ObjectId('573a1394f29313caabcdf772'), 'title': 'Late Chrysanthemums'},
#  {'_id': ObjectId('573a1394f29313caabcdf7cc'),
#   'title': 'The Crucified Lovers'},
#  {'_id': ObjectId('573a1394f29313caabcdf88c'), 'title': 'Godzilla'},
#  {'_id': ObjectId('573a1394f29313caabcdf98e'), 'title': 'Twenty-Four Eyes'},
#  {'_id': ObjectId('573a1394f29313caabcdf996'), 'title': 'The Garden of Women'},
#  {'_id': ObjectId('573a1394f29313caabcdfa1c'),
#   'title': 'Samurai I: Musashi Miyamoto'},
#  {'_id': ObjectId('573a1394f29313caabcdfa27'), 'title': 'Sansho the Bailiff'},
#  {'_id': ObjectId('573a1394f29313caabcdfa3e'), 'title': 'Seven Samurai'},
#  {'_id': ObjectId('573a1394f29313caabcdfb13'),
#   'title': 'Sound of the Mountain'},
#  {'_id': ObjectId('573a1394f29313caabcdfd07'),
#   'title': 'I Live in Fear: Record of a Living Being'},
#  {'_id': ObjectId('573a1394f29313caabcdfdfd'),
#   'title': 'She Was Like a Wild Chrysanthemum'},
#  {'_id': ObjectId('573a1394f29313caabcdfed1'), 'title': 'Taira Clan Saga'},
#  {'_id': ObjectId('573a1394f29313caabcdff5f'), 'title': 'Floating Clouds'},
#  {'_id': ObjectId('573a1394f29313caabcdff6d'), 'title': 'Yèkihi'},
#  {'_id': ObjectId('573a1394f29313caabcdffe8'), 'title': 'Street of Shame'},
#  {'_id': ObjectId('573a1394f29313caabce0036'), 'title': 'The Burmese Harp'},
#  {'_id': ObjectId('573a1394f29313caabce0243'), 'title': 'Flowing'},
#  {'_id': ObjectId('573a1394f29313caabce03a2'), 'title': 'Warning from Space'},
#  {'_id': ObjectId('573a1394f29313caabce04a6'),
#   'title': 'A Sun-Tribe Myth from the Bakumatsu Era'},
#  {'_id': ObjectId('573a1394f29313caabce0561'), 'title': 'Donzoko'},
#  {'_id': ObjectId('573a1394f29313caabce0667'), 'title': 'Throne of Blood'},
#  {'_id': ObjectId('573a1394f29313caabce08b6'),
#   'title': 'Times of Joy and Sorrow'},
#  {'_id': ObjectId('573a1394f29313caabce0a2a'), 'title': 'Conflagration'},
#  {'_id': ObjectId('573a1394f29313caabce0ab8'), 'title': 'Equinox Flower'},
#  {'_id': ObjectId('573a1394f29313caabce0b13'), 'title': 'The Hidden Fortress'},
#  {'_id': ObjectId('573a1394f29313caabce0bb3'), 'title': 'The Rickshaw Man'},
#  {'_id': ObjectId('573a1394f29313caabce0bd7'), 'title': 'Stolen Desire'},
#  {'_id': ObjectId('573a1394f29313caabce0bd8'), 'title': 'Ballad of Narayama'},
#  {'_id': ObjectId('573a1394f29313caabce0f4a'), 'title': 'Hiroshima Mon Amour'},
#  {'_id': ObjectId('573a1394f29313caabce0f9d'), 'title': 'Odd Obsession'},
#  {'_id': ObjectId('573a1394f29313caabce101b'),
#   'title': 'The Human Condition II: Road to Eternity'},
#  {'_id': ObjectId('573a1394f29313caabce1020'), 'title': 'Fires on the Plain'},
#  {'_id': ObjectId('573a1394f29313caabce1025'),
#   'title': 'The Human Condition I: No Greater Love'},
#  {'_id': ObjectId('573a1395f29313caabce11ef'), 'title': 'Late Autumn'},
#  {'_id': ObjectId('573a1395f29313caabce12e8'), 'title': 'The River Fuefuki'},
#  {'_id': ObjectId('573a1395f29313caabce13e0'),
#   'title': 'My Face Red in the Sunset'},
#  {'_id': ObjectId('573a1395f29313caabce149a'), 'title': 'Naked Youth'},
#  {'_id': ObjectId('573a1395f29313caabce14f3'), 'title': "The Sun's Burial"},
#  {'_id': ObjectId('573a1395f29313caabce1547'), 'title': 'The Bad Sleep Well'},
#  {'_id': ObjectId('573a1395f29313caabce1634'),
#   'title': 'Pigs and Battleships'},
#  {'_id': ObjectId('573a1395f29313caabce16b8'), 'title': 'Immortal Love'},
#  {'_id': ObjectId('573a1395f29313caabce1791'), 'title': 'The End of Summer'},
#  {'_id': ObjectId('573a1395f29313caabce1814'), 'title': 'Mothra'},
#  {'_id': ObjectId('573a1395f29313caabce1841'),
#   'title': "The Human Condition III: A Soldier's Prayer"},
#  {'_id': ObjectId('573a1395f29313caabce196c'), 'title': 'A Wife Confesses'},
#  {'_id': ObjectId('573a1395f29313caabce19bb'), 'title': 'Yojimbo'},
#  {'_id': ObjectId('573a1395f29313caabce1b54'), 'title': 'The Naked Island'},
#  {'_id': ObjectId('573a1395f29313caabce1b72'), 'title': 'Harakiri'},
#  {'_id': ObjectId('573a1395f29313caabce1bc0'), 'title': 'The Inheritance'},
#  {'_id': ObjectId('573a1395f29313caabce1ceb'), 'title': 'Sanjuro'},
#  {'_id': ObjectId('573a1395f29313caabce1cec'), 'title': 'An Autumn Afternoon'},
#  {'_id': ObjectId('573a1395f29313caabce1ddf'),
#   'title': 'The Tale of Zatoichi'},
#  {'_id': ObjectId('573a1395f29313caabce1de9'),
#   'title': 'The Tale of Zatoichi'},
#  {'_id': ObjectId('573a1395f29313caabce2068'), 'title': 'The Insect Woman'},
#  {'_id': ObjectId('573a1395f29313caabce20fc'),
#   'title': 'New Tale of Zatoichi'},
#  {'_id': ObjectId('573a1395f29313caabce212f'), 'title': 'High and Low'},
#  {'_id': ObjectId('573a1395f29313caabce21ca'), 'title': "An Actor's Revenge"},
#  {'_id': ObjectId('573a1395f29313caabce21d8'),
#   'title': 'Zatoichi the Fugitive'},
#  {'_id': ObjectId('573a1395f29313caabce2227'),
#   'title': 'Intentions of Murder'},
#  {'_id': ObjectId('573a1395f29313caabce2401'), 'title': 'Kwaidan'},
#  {'_id': ObjectId('573a1395f29313caabce2430'), 'title': 'Yearning'},
#  {'_id': ObjectId('573a1395f29313caabce2477'), 'title': 'Onibaba'},
#  {'_id': ObjectId('573a1395f29313caabce254c'), 'title': 'Woman in the Dunes'},
#  {'_id': ObjectId('573a1395f29313caabce263e'), 'title': 'Red Beard'},
#  {'_id': ObjectId('573a1395f29313caabce29ac'), 'title': 'Tokyo Olympiad'},
#  {'_id': ObjectId('573a1395f29313caabce2c7a'), 'title': 'The Pornographers'},
#  {'_id': ObjectId('573a1395f29313caabce2e5e'), 'title': 'The Face of Another'},
#  {'_id': ObjectId('573a1395f29313caabce30a9'),
#   'title': 'Daikaijè kèchèsen: Gamera tai Gyaosu'},
#  {'_id': ObjectId('573a1395f29313caabce313d'), 'title': 'Samurai Rebellion'},
#  {'_id': ObjectId('573a1395f29313caabce31f5'), 'title': "Japan's Longest Day"},
#  {'_id': ObjectId('573a1395f29313caabce31f7'), 'title': 'A Man Vanishes'},
#  {'_id': ObjectId('573a1396f29313caabce364a'),
#   'title': 'Profound Desires of the Gods'},
#  {'_id': ObjectId('573a1396f29313caabce3659'), 'title': 'Kill!'},
#  {'_id': ObjectId('573a1396f29313caabce3676'), 'title': 'Death by Hanging'},
#  {'_id': ObjectId('573a1396f29313caabce389d'),
#   'title': 'Rengè kantai shirei chèkan: Yamamoto Isoroku'},
#  {'_id': ObjectId('573a1396f29313caabce3aba'), 'title': 'Goyokin'},
#  {'_id': ObjectId('573a1396f29313caabce3c39'), 'title': 'Am I Trying'},
#  {'_id': ObjectId('573a1396f29313caabce3cee'), 'title': 'Double Suicide'},
#  {'_id': ObjectId('573a1396f29313caabce3f93'), 'title': "Dodes'ka-den"},
#  {'_id': ObjectId('573a1396f29313caabce4221'),
#   'title': 'Shinsengumi: Assassins of Honor'},
#  {'_id': ObjectId('573a1396f29313caabce4280'), 'title': 'Tora! Tora! Tora!'},
#  {'_id': ObjectId('573a1396f29313caabce4305'),
#   'title': 'Zatoichi Meets the One-Armed Swordsman'},
#  {'_id': ObjectId('573a1396f29313caabce431f'), 'title': 'The Ceremony'},
#  {'_id': ObjectId('573a1396f29313caabce44fb'), 'title': 'The Ceremony'},
#  {'_id': ObjectId('573a1396f29313caabce456d'), 'title': 'Inochi bè ni furè'},
#  {'_id': ObjectId('573a1396f29313caabce467b'),
#   'title': "Tora-san's Love Call"},
#  {'_id': ObjectId('573a1396f29313caabce4746'), 'title': 'Silence'},
#  {'_id': ObjectId('573a1396f29313caabce509c'),
#   'title': 'Battles Without Honor and Humanity'},
#  {'_id': ObjectId('573a1396f29313caabce5419'),
#   'title': 'Kenji Mizoguchi: The Life of a Film Director'},
#  {'_id': ObjectId('573a1396f29313caabce5434'),
#   'title': 'Belladonna of Sadness'},
#  {'_id': ObjectId('573a1396f29313caabce54e6'),
#   'title': 'Pastoral Hide and Seek'},
#  {'_id': ObjectId('573a1396f29313caabce54ea'), 'title': 'Dersu Uzala'},
#  {'_id': ObjectId('573a1396f29313caabce55ab'), 'title': 'Himiko'},
#  {'_id': ObjectId('573a1396f29313caabce58da'),
#   'title': "Zatoichi's Conspiracy"},
#  {'_id': ObjectId('573a1397f29313caabce5cc0'),
#   'title': "Tora-san's Rise and Fall"},
#  {'_id': ObjectId('573a1397f29313caabce5d56'), 'title': 'Sandakan 8'},
#  {'_id': ObjectId('573a1397f29313caabce5f02'),
#   'title': 'In the Realm of the Senses'},
#  {'_id': ObjectId('573a1397f29313caabce66b2'), 'title': 'House'},
#  {'_id': ObjectId('573a1397f29313caabce6991'),
#   'title': 'Who Are the DeBolts? [And Where Did They Get 19 Kids?]'},
#  {'_id': ObjectId('573a1397f29313caabce6a6f'), 'title': 'Empire of Passion'},
#  {'_id': ObjectId('573a1397f29313caabce6f53'), 'title': 'Message from Space'},
#  {'_id': ObjectId('573a1397f29313caabce721d'), 'title': 'Vengeance is Mine'},
#  {'_id': ObjectId('573a1397f29313caabce73f0'), 'title': 'Nutcracker Fantasy'},
#  {'_id': ObjectId('573a1397f29313caabce749c'),
#   'title': 'The Castle of Cagliostro'},
#  {'_id': ObjectId('573a1397f29313caabce7831'), 'title': 'Galaxy Express 999'},
#  {'_id': ObjectId('573a1397f29313caabce790d'), 'title': 'Kagemusha'},
#  {'_id': ObjectId('573a1397f29313caabce7920'),
#   'title': 'Kuruizaki sanda rodo'},
#  {'_id': ObjectId('573a1397f29313caabce7b98'), 'title': 'Tsigoineruwaizen'},
#  {'_id': ObjectId('573a1397f29313caabce7df0'), 'title': 'Muddy River'},
#  {'_id': ObjectId('573a1397f29313caabce7e11'), 'title': 'Why Not?'},
#  {'_id': ObjectId('573a1397f29313caabce7f29'), 'title': 'Heat-Haze Theatre'},
#  {'_id': ObjectId('573a1397f29313caabce7f97'),
#   'title': 'Samurai Reincarnation'},
#  {'_id': ObjectId('573a1397f29313caabce80f6'), 'title': 'Gauche the Cellist'},
#  {'_id': ObjectId('573a1397f29313caabce84e8'),
#   'title': 'The House Where Evil Dwells'},
#  {'_id': ObjectId('573a1397f29313caabce8576'), 'title': 'The Last Unicorn'},
#  {'_id': ObjectId('573a1397f29313caabce8602'),
#   'title': 'The Ballad of Narayama'},
#  {'_id': ObjectId('573a1397f29313caabce8779'),
#   'title': 'I Are You, You Am Me'},
#  {'_id': ObjectId('573a1397f29313caabce8935'), 'title': 'Barefoot Gen'},
#  {'_id': ObjectId('573a1397f29313caabce8be3'),
#   'title': 'Merry Christmas Mr. Lawrence'},
#  {'_id': ObjectId('573a1397f29313caabce8c23'), 'title': 'Antarctica'},
#  {'_id': ObjectId('573a1397f29313caabce8d18'),
#   'title': 'Legend of Eight Samurai'},
#  {'_id': ObjectId('573a1397f29313caabce8d35'), 'title': 'The Makioka Sisters'},
#  {'_id': ObjectId('573a1398f29313caabce8dce'),
#   'title': 'The Little Girl Who Conquered Time'},
#  {'_id': ObjectId('573a1398f29313caabce912e'), 'title': 'Godzilla 1985'},
#  {'_id': ObjectId('573a1398f29313caabce9156'), 'title': 'The Crazy Family'},
#  {'_id': ObjectId('573a1398f29313caabce91ec'),
#   'title': 'Nausicaè of the Valley of the Wind'},
#  {'_id': ObjectId('573a1398f29313caabce91ee'), 'title': 'The Family Game'},
#  {'_id': ObjectId('573a1398f29313caabce9226'),
#   'title': 'Legend of Eight Samurai'},
#  {'_id': ObjectId('573a1398f29313caabce9495'), 'title': 'Typhoon Club'},
#  {'_id': ObjectId('573a1398f29313caabce9508'),
#   'title': 'Nausicaè of the Valley of the Wind'},
#  {'_id': ObjectId('573a1398f29313caabce9834'),
#   'title': "Kenji Miyazawa's Night on the Galactic Express"},
#  {'_id': ObjectId('573a1398f29313caabce9851'), 'title': 'Gymkata'},
#  {'_id': ObjectId('573a1398f29313caabce994e'), 'title': 'Love Hotel'},
#  {'_id': ObjectId('573a1398f29313caabce99b2'),
#   'title': 'Mishima: A Life in Four Chapters'},
#  {'_id': ObjectId('573a1398f29313caabce99fd'), 'title': 'The Ninja Wars'},
#  {'_id': ObjectId('573a1398f29313caabce9a3e'), 'title': 'The Funeral'},
#  {'_id': ObjectId('573a1398f29313caabce9ab7'), 'title': 'Ran'},
#  {'_id': ObjectId('573a1398f29313caabcea2ed'), 'title': 'Tampopo'},
#  {'_id': ObjectId('573a1398f29313caabcea2ef'), 'title': 'Castle in the Sky'},
#  {'_id': ObjectId('573a1398f29313caabcea314'),
#   'title': 'The Transformers: The Movie'},
#  {'_id': ObjectId('573a1398f29313caabcea55e'),
#   'title': 'The Brave Little Toaster'},
#  {'_id': ObjectId('573a1398f29313caabcea662'),
#   'title': "The Emperor's Naked Army Marches On"},
#  {'_id': ObjectId('573a1398f29313caabcea69a'), 'title': 'Fatal Beauty'},
#  {'_id': ObjectId('573a1398f29313caabcea701'), 'title': 'Hachi-ko'},
#  {'_id': ObjectId('573a1398f29313caabcea80b'),
#   'title': 'Legend of the Forest'},
#  {'_id': ObjectId('573a1398f29313caabcea883'), 'title': 'A Taxing Woman'},
#  {'_id': ObjectId('573a1398f29313caabceab80'), 'title': 'Brightness'},
#  {'_id': ObjectId('573a1398f29313caabceac96'), 'title': 'Akira'},
#  {'_id': ObjectId('573a1398f29313caabcead3f'),
#   'title': 'Bright Lights, Big City'},
#  {'_id': ObjectId('573a1398f29313caabceaf29'),
#   'title': 'Grave of the Fireflies'},
#  {'_id': ObjectId('573a1398f29313caabceb023'),
#   'title': "A Taxing Woman's Return"},
#  {'_id': ObjectId('573a1398f29313caabceb293'),
#   'title': 'Tetsuo, the Iron Man'},
#  {'_id': ObjectId('573a1398f29313caabceb2b3'), 'title': 'My Neighbor Totoro'},
#  {'_id': ObjectId('573a1398f29313caabceb595'),
#   'title': 'The Adventures of Milo and Otis'},
#  {'_id': ObjectId('573a1398f29313caabceb712'),
#   'title': 'Godzilla vs. Biollante'},
#  {'_id': ObjectId('573a1398f29313caabceb826'), 'title': 'Black Rain'},
#  {'_id': ObjectId('573a1398f29313caabceb872'),
#   'title': "Kiki's Delivery Service"},
#  {'_id': ObjectId('573a1398f29313caabceb878'), 'title': 'The Mahabharata'},
#  {'_id': ObjectId('573a1398f29313caabceb8f2'), 'title': 'Mystery Train'},
#  {'_id': ObjectId('573a1398f29313caabceb9ef'), 'title': 'Rikyu'},
#  {'_id': ObjectId('573a1398f29313caabceba7a'), 'title': 'Violent Cop'},
#  {'_id': ObjectId('573a1398f29313caabcebccf'), 'title': 'Boiling Point'},
#  {'_id': ObjectId('573a1398f29313caabcebcd3'),
#   'title': 'Tales of a Golden Geisha'},
#  {'_id': ObjectId('573a1398f29313caabcebf5e'), 'title': 'The Garden'},
#  {'_id': ObjectId('573a1398f29313caabcebf8a'), 'title': 'Graveyard Shift'},
#  {'_id': ObjectId('573a1398f29313caabcebfc6'), 'title': 'Heaven and Earth'},
#  {'_id': ObjectId('573a1399f29313caabcec02a'), 'title': 'Iron & Silk'},
#  {'_id': ObjectId('573a1399f29313caabcec062'), 'title': 'Ju Dou'},
#  {'_id': ObjectId('573a1399f29313caabcec130'), 'title': 'Memphis Belle'},
#  {'_id': ObjectId('573a1399f29313caabcec2b1'), 'title': 'Reversal of Fortune'},
#  {'_id': ObjectId('573a1399f29313caabcec32f'), 'title': 'Solar Crisis'},
#  {'_id': ObjectId('573a1399f29313caabcec47d'), 'title': 'Dreams'},
#  {'_id': ObjectId('573a1399f29313caabcec794'), 'title': 'Edward II'},
#  {'_id': ObjectId('573a1399f29313caabcec80b'),
#   'title': "Chizuko's Younger Sister"},
#  {'_id': ObjectId('573a1399f29313caabcec836'),
#   'title': 'Godzilla vs. King Ghidorah'},
#  {'_id': ObjectId('573a1399f29313caabcec83b'), 'title': 'Rhapsody in August'},
#  {'_id': ObjectId('573a1399f29313caabcec84e'), 'title': 'Guyver'},
#  {'_id': ObjectId('573a1399f29313caabcec8b6'), 'title': 'The Indian Runner'},
#  {'_id': ObjectId('573a1399f29313caabceca29'), 'title': 'Musuko'},
#  {'_id': ObjectId('573a1399f29313caabceca35'), 'title': 'Naked Lunch'},
#  {'_id': ObjectId('573a1399f29313caabceca56'), 'title': 'Night on Earth'},
#  {'_id': ObjectId('573a1399f29313caabcecade'), 'title': 'Point Break'},
#  {'_id': ObjectId('573a1399f29313caabcecb13'), 'title': "Prospero's Books"},
#  {'_id': ObjectId('573a1399f29313caabcecc16'), 'title': 'The Super'},
#  {'_id': ObjectId('573a1399f29313caabcecd3a'), 'title': 'Yumeji'},
#  {'_id': ObjectId('573a1399f29313caabcecebf'), 'title': 'A Scene at the Sea'},
#  {'_id': ObjectId('573a1399f29313caabcecf6c'),
#   'title': 'A Brief History of Time'},
#  {'_id': ObjectId('573a1399f29313caabcecfa5'), 'title': 'Chaplin'},
#  {'_id': ObjectId('573a1399f29313caabced01a'), 'title': 'The Crying Game'},
#  {'_id': ObjectId('573a1399f29313caabced067'), 'title': 'Dr. Giggles'},
#  {'_id': ObjectId('573a1399f29313caabced137'),
#   'title': 'Godzilla and Mothra: The Battle for Earth'},
#  {'_id': ObjectId('573a1399f29313caabced140'), 'title': 'Gè-hime'},
#  {'_id': ObjectId('573a1399f29313caabced1a6'), 'title': 'Howards End'},
#  {'_id': ObjectId('573a1399f29313caabced1cc'), 'title': 'In the Soup'},
#  {'_id': ObjectId('573a1399f29313caabced23c'), 'title': 'Kira kira hikaru'},
#  {'_id': ObjectId('573a1399f29313caabced273'), 'title': 'Porco Rosso'},
#  {'_id': ObjectId('573a1399f29313caabced285'), 'title': 'The Lawnmower Man'},
#  {'_id': ObjectId('573a1399f29313caabced2be'),
#   'title': 'Little Nemo: Adventures in Slumberland'},
#  {'_id': ObjectId('573a1399f29313caabced2ea'), 'title': 'Malcolm X'},
#  {'_id': ObjectId('573a1399f29313caabced33c'), 'title': 'Minbè no onna'},
#  {'_id': ObjectId('573a1399f29313caabced370'), 'title': 'Mr. Baseball'},
#  {'_id': ObjectId('573a1399f29313caabced418'), 'title': 'Highway Patrolman'},
#  {'_id': ObjectId('573a1399f29313caabced531'), 'title': "Sumo Do, Sumo Don't"},
#  {'_id': ObjectId('573a1399f29313caabced5c9'),
#   'title': 'Tetsuo II: Body Hammer'},
#  {'_id': ObjectId('573a1399f29313caabced608'), 'title': 'Tokyo Decadence'},
#  {'_id': ObjectId('573a1399f29313caabced646'), 'title': 'Unlawful Entry'},
#  {'_id': ObjectId('573a1399f29313caabced64e'), 'title': 'Used People'},
#  {'_id': ObjectId('573a1399f29313caabced684'), 'title': 'Visions of Light'},
#  {'_id': ObjectId('573a1399f29313caabced91c'), 'title': 'Blue'},
#  {'_id': ObjectId('573a1399f29313caabcedb5c'),
#   'title': 'Godzilla vs. Mechagodzilla II'},
#  {'_id': ObjectId('573a1399f29313caabcedd26'), 'title': 'Madadayo'},
#  {'_id': ObjectId('573a1399f29313caabcededa'),
#   'title': 'Return of the Living Dead III'},
#  {'_id': ObjectId('573a1399f29313caabcedfbf'), 'title': 'Sonatine'},
#  {'_id': ObjectId('573a1399f29313caabcee14e'), 'title': 'Wittgenstein'},
#  {'_id': ObjectId('573a1399f29313caabcee2e2'), 'title': '3 Ninjas Kick Back'},
#  {'_id': ObjectId('573a1399f29313caabcee2ef'), 'title': 'Cold Fever'},
#  {'_id': ObjectId('573a1399f29313caabcee617'),
#   'title': "Mary Shelley's Frankenstein"},
#  {'_id': ObjectId('573a1399f29313caabcee64d'), 'title': 'The Getaway'},
#  {'_id': ObjectId('573a1399f29313caabcee6b2'), 'title': 'Pom Poko'},
#  {'_id': ObjectId('573a1399f29313caabcee840'), 'title': 'Macross Plus'},
#  {'_id': ObjectId('573a1399f29313caabceea3e'), 'title': 'Rampo'},
#  {'_id': ObjectId('573a1399f29313caabceeb1c'), 'title': '47 Ronin'},
#  {'_id': ObjectId('573a1399f29313caabceeb28'), 'title': 'Shopping'},
#  {'_id': ObjectId('573a1399f29313caabceeb90'), 'title': 'Street Fighter'},
#  {'_id': ObjectId('573a1399f29313caabceec0e'), 'title': 'Timecop'},
#  {'_id': ObjectId('573a1399f29313caabceec83'), 'title': 'Undo'},
#  {'_id': ObjectId('573a1399f29313caabceed02'), 'title': 'War of the Buttons'},
#  {'_id': ObjectId('573a139af29313caabcef10b'), 'title': 'Crying Freeman'},
#  {'_id': ObjectId('573a139af29313caabcef150'), 'title': 'Dead Man'},
#  {'_id': ObjectId('573a139af29313caabcef2c2'),
#   'title': 'Godzilla vs. Destoroyah'},
#  {'_id': ObjectId('573a139af29313caabcef2d4'), 'title': 'The Five'},
#  {'_id': ObjectId('573a139af29313caabcef307'),
#   'title': 'Good Men, Good Women'},
#  {'_id': ObjectId('573a139af29313caabcef3a4'),
#   'title': 'Institute Benjamenta, or This Dream That One Calls Human Life'},
#  {'_id': ObjectId('573a139af29313caabcef40c'), 'title': 'Kamikaze Taxi'},
#  {'_id': ObjectId('573a139af29313caabcef41e'), 'title': 'Born to Be Wild'},
#  {'_id': ObjectId('573a139af29313caabcef42c'), 'title': 'Ghost in the Shell'},
#  {'_id': ObjectId('573a139af29313caabcef4c5'), 'title': 'Maborosi'},
#  {'_id': ObjectId('573a139af29313caabcef4d0'), 'title': 'Love Letter'},
#  {'_id': ObjectId('573a139af29313caabcef511'), 'title': 'Memories'},
#  {'_id': ObjectId('573a139af29313caabcef539'),
#   'title': 'Mighty Morphin Power Rangers: The Movie'},
#  {'_id': ObjectId('573a139af29313caabcef654'), 'title': 'Picture Bride'},
#  {'_id': ObjectId('573a139af29313caabcef6a8'),
#   'title': 'The Quick and the Dead'},
#  {'_id': ObjectId('573a139af29313caabcef744'), 'title': 'Screamers'},
#  {'_id': ObjectId('573a139af29313caabcef7a7'), 'title': 'Smoke'},
#  {'_id': ObjectId('573a139af29313caabcef8a4'), 'title': 'Tokyo Fist'},
#  {'_id': ObjectId('573a139af29313caabcefca1'), 'title': 'Box of Moon Light'},
#  {'_id': ObjectId('573a139af29313caabcefd73'), 'title': 'Non-Stop'},
#  {'_id': ObjectId('573a139af29313caabcefed2'), 'title': 'The Break'},
#  {'_id': ObjectId('573a139af29313caabcf0031'),
#   'title': 'Kama Sutra: A Tale of Love'},
#  {'_id': ObjectId('573a139af29313caabcf0035'), 'title': 'Kathapurushan'},
#  {'_id': ObjectId('573a139af29313caabcf0051'), 'title': 'Kids Return'},
#  {'_id': ObjectId('573a139af29313caabcf01bd'),
#   'title': 'Goodbye, South, Goodbye'},
#  {'_id': ObjectId('573a139af29313caabcf02a1'), 'title': 'Picnic'},
#  {'_id': ObjectId('573a139af29313caabcf0377'),
#   'title': 'Sgt. Kabukiman N.Y.P.D.'},
#  {'_id': ObjectId('573a139af29313caabcf0392'), 'title': 'Shall We Dance?'},
#  {'_id': ObjectId('573a139af29313caabcf0780'), 'title': 'Bent'},
#  {'_id': ObjectId('573a139af29313caabcf080c'), 'title': 'Happy Together'},
#  {'_id': ObjectId('573a139af29313caabcf082c'), 'title': 'Chinese Box'},
#  {'_id': ObjectId('573a139af29313caabcf098b'), 'title': 'Fireworks'},
#  {'_id': ObjectId('573a139af29313caabcf0a12'), 'title': 'The Jackal'},
#  {'_id': ObjectId('573a139af29313caabcf0abb'),
#   'title': 'Love Is the Devil: Study for a Portrait of Francis Bacon'},
#  {'_id': ObjectId('573a139af29313caabcf0b20'), 'title': 'Suzaku'},
#  {'_id': ObjectId('573a139af29313caabcf0b34'), 'title': 'Princess Mononoke'},
#  {'_id': ObjectId('573a139af29313caabcf0bac'), 'title': 'Onibi'},
#  {'_id': ObjectId('573a139af29313caabcf0bec'), 'title': 'Phantoms'},
#  {'_id': ObjectId('573a139af29313caabcf0c09'), 'title': 'Postman Blues'},
#  {'_id': ObjectId('573a139af29313caabcf0c21'), 'title': 'Primary Colors'},
#  {'_id': ObjectId('573a139af29313caabcf0c4b'), 'title': 'The Relic'},
#  {'_id': ObjectId('573a139af29313caabcf0ca5'), 'title': 'Moonlight Serenade'},
#  {'_id': ObjectId('573a139af29313caabcf0d66'), 'title': 'A Simple Plan'},
#  {'_id': ObjectId('573a139af29313caabcf0dae'),
#   'title': 'Turbo: A Power Rangers Movie'},
#  {'_id': ObjectId('573a139af29313caabcf0db4'), 'title': 'The Eel'},
#  {'_id': ObjectId('573a139af29313caabcf0e20'), 'title': 'Wilde'},
#  {'_id': ObjectId('573a139af29313caabcf0e4a'), 'title': 'Yume no ginga'},
#  {'_id': ObjectId('573a139af29313caabcf0ebe'), 'title': 'Illuminata'},
#  {'_id': ObjectId('573a139af29313caabcf0ec1'), 'title': 'Godzilla'},
#  {'_id': ObjectId('573a139af29313caabcf0f3c'), 'title': 'Vampires'},
#  {'_id': ObjectId('573a139af29313caabcf13b8'), 'title': 'Kuroneko'},
#  {'_id': ObjectId('573a139af29313caabcf14fa'), 'title': 'Vostochnaya elegiya'},
#  {'_id': ObjectId('573a139af29313caabcf174b'),
#   'title': 'Fudoh: The New Generation'},
#  {'_id': ObjectId('573a139af29313caabcf17f2'),
#   'title': "Zatoichi's Conspiracy"},
#  {'_id': ObjectId('573a139af29313caabcf1834'),
#   'title': 'Fight, Zatoichi, Fight'},
#  {'_id': ObjectId('573a139af29313caabcf183d'), 'title': "Zatoichi's Revenge"},
#  {'_id': ObjectId('573a139af29313caabcf1aa6'), 'title': 'The Cure'},
#  {'_id': ObjectId('573a139af29313caabcf1b53'), 'title': 'Tokyo Trial'},
#  {'_id': ObjectId('573a139af29313caabcf1d9b'),
#   'title': 'Patlabor 2: The Movie'},
#  {'_id': ObjectId('573a139af29313caabcf20ee'), 'title': 'Man on the Moon'},
#  {'_id': ObjectId('573a139bf29313caabcf273e'), 'title': 'Sèpè no onna'},
#  {'_id': ObjectId('573a139bf29313caabcf3d5d'),
#   'title': 'Welcome Back, Mr. McDonald'},
#  {'_id': ObjectId('573a139bf29313caabcf4195'), 'title': 'I Will Buy You'},
#  {'_id': ObjectId('573a139bf29313caabcf437a'),
#   'title': 'Somewhere Under the Broad Sky'},
#  {'_id': ObjectId('573a139bf29313caabcf43a2'), 'title': 'Sincerity'},
#  {'_id': ObjectId('573a139bf29313caabcf4631'), 'title': 'Kaseki'},
#  {'_id': ObjectId('573a139cf29313caabcf5c44'), 'title': "Isn't She Great"},
#  {'_id': ObjectId('573a139cf29313caabcf5dfd'), 'title': 'Sweet Home'},
#  {'_id': ObjectId('573a139cf29313caabcf5f44'),
#   'title': 'The Bird People in China'},
#  {'_id': ObjectId('573a139cf29313caabcf5fce'), 'title': 'Rainy Dog'},
#  {'_id': ObjectId('573a139cf29313caabcf6836'), 'title': 'Sada'},
#  {'_id': ObjectId('573a139cf29313caabcf6e7d'), 'title': 'April Story'},
#  {'_id': ObjectId('573a139cf29313caabcf6ec5'),
#   'title': 'Lara Croft: Tomb Raider'},
#  {'_id': ObjectId('573a139cf29313caabcf8463'), 'title': 'Pola X'},
#  {'_id': ObjectId('573a139cf29313caabcf8990'), 'title': 'Typhoon Club'},
#  {'_id': ObjectId('573a139df29313caabcf92aa'), 'title': 'Dr. Akagi'},
#  {'_id': ObjectId('573a139df29313caabcf95b0'), 'title': 'Flowers of Shanghai'},
#  {'_id': ObjectId('573a139df29313caabcf9701'), 'title': 'Perfect Blue'},
#  {'_id': ObjectId('573a139df29313caabcfa90b'), 'title': 'Message from Space'},
#  {'_id': ObjectId('573a139df29313caabcfad15'),
#   'title': 'The Emperor and the Assassin'},
#  {'_id': ObjectId('573a139df29313caabcfb000'), 'title': 'Bullet Ballet'},
#  {'_id': ObjectId('573a139df29313caabcfb081'), 'title': 'Onimasa'},
#  {'_id': ObjectId('573a139df29313caabcfb2b7'), 'title': 'Assassination'},
#  {'_id': ObjectId('573a139df29313caabcfb4b7'),
#   'title': 'Ninja, a Band of Assassins'},
#  {'_id': ObjectId('573a139df29313caabcfb4fa'),
#   'title': 'Adventures of Zatoichi'},
#  {'_id': ObjectId('573a139df29313caabcfb574'), 'title': 'After Life'},
#  {'_id': ObjectId('573a139df29313caabcfb806'),
#   'title': 'Ghost Dog: The Way of the Samurai'},
#  {'_id': ObjectId('573a139df29313caabcfb9d2'), 'title': 'Malcolm X'},
#  {'_id': ObjectId('573a139ef29313caabcfc219'),
#   'title': 'Battles Without Honor and Humanity'},
#  {'_id': ObjectId('573a139ef29313caabcfc3d2'), 'title': 'Love & Pop'},
#  {'_id': ObjectId('573a139ef29313caabcfc715'),
#   'title': 'Neon Genesis Evangelion: The End of Evangelion'},
#  {'_id': ObjectId('573a139ef29313caabcfc71f'),
#   'title': 'Neon Genesis Evangelion: Death & Rebirth'},
#  {'_id': ObjectId('573a139ef29313caabcfc8a3'), 'title': 'Luna Papa'},
#  {'_id': ObjectId('573a139ef29313caabcfc99c'), 'title': 'Samurai Fiction'},
#  {'_id': ObjectId('573a139ef29313caabcfce2b'), 'title': 'Shall We Dance?'},
#  {'_id': ObjectId('573a139ef29313caabcfd63a'),
#   'title': 'Final Fantasy: The Spirits Within'},
#  {'_id': ObjectId('573a139ef29313caabcfe1dc'),
#   'title': "Kiki's Delivery Service"},
#  {'_id': ObjectId('573a139ef29313caabcfe969'), 'title': 'Ring'},
#  {'_id': ObjectId('573a139ef29313caabcfeaeb'), 'title': 'Castle in the Sky'},
#  {'_id': ObjectId('573a139ff29313caabcff4e0'), 'title': 'After the Rain'},
#  {'_id': ObjectId('573a139ff29313caabd0004f'), 'title': 'Wonder Boys'},
#  {'_id': ObjectId('573a139ff29313caabd006d3'),
#   'title': "Zatoichi's Cane-sword"},
#  {'_id': ObjectId('573a139ff29313caabd006f1'),
#   'title': 'Fight, Zatoichi, Fight'},
#  {'_id': ObjectId('573a139ff29313caabd00c73'), 'title': 'Sukeban Deka'},
#  {'_id': ObjectId('573a139ff29313caabd00e06'), 'title': 'Godzilla 2000'},
#  {'_id': ObjectId('573a139ff29313caabd01276'), 'title': 'Something Like It'},
#  {'_id': ObjectId('573a139ff29313caabd0157a'),
#   'title': 'Pokèmon: The First Movie - Mewtwo Strikes Back'},
#  {'_id': ObjectId('573a139ff29313caabd017a3'), 'title': 'Katatsumori'},
#  {'_id': ObjectId('573a139ff29313caabd017ee'), 'title': 'Embracing'},
#  {'_id': ObjectId('573a139ff29313caabd01944'),
#   'title': "Zatoichi's Flashing Sword"},
#  {'_id': ObjectId('573a139ff29313caabd01f46'),
#   'title': 'Jin-Roh: The Wolf Brigade'},
#  {'_id': ObjectId('573a13a0f29313caabd02f75'),
#   'title': 'Godzilla, King of the Monsters!'},
#  {'_id': ObjectId('573a13a0f29313caabd03037'), 'title': 'License to Live'},
#  {'_id': ObjectId('573a13a0f29313caabd0378c'), 'title': 'Kikujiro'},
#  {'_id': ObjectId('573a13a0f29313caabd037a2'), 'title': 'Kikujiro'},
#  {'_id': ObjectId('573a13a0f29313caabd037e6'), 'title': 'Moloch'},
#  {'_id': ObjectId('573a13a0f29313caabd03871'),
#   'title': "Zatoichi: The Blind Swordsman's Pilgrimage"},
#  {'_id': ObjectId('573a13a0f29313caabd03e5a'), 'title': 'Charisma'},
#  {'_id': ObjectId('573a13a0f29313caabd03f11'),
#   'title': "Kiki's Delivery Service"},
#  {'_id': ObjectId('573a13a0f29313caabd0426e'), 'title': 'The Castle of Sand'},
#  {'_id': ObjectId('573a13a0f29313caabd04a51'), 'title': 'Trouble Every Day'},
#  {'_id': ObjectId('573a13a0f29313caabd054c2'),
#   'title': 'Ghost Dog: The Way of the Samurai'},
#  {'_id': ObjectId('573a13a0f29313caabd05534'),
#   'title': 'The Old Man and the Sea'},
#  {'_id': ObjectId('573a13a0f29313caabd05725'), 'title': 'Moonlight Whispers'},
#  {'_id': ObjectId('573a13a0f29313caabd05f30'), 'title': 'Sèseiji'},
#  {'_id': ObjectId('573a13a0f29313caabd0618e'), 'title': 'Princess Mononoke'},
#  {'_id': ObjectId('573a13a0f29313caabd0648e'), 'title': 'Vengo'},
#  {'_id': ObjectId('573a13a1f29313caabd06bcc'), 'title': 'Gohatto'},
#  {'_id': ObjectId('573a13a1f29313caabd07da7'), 'title': 'Ring 2'},
#  {'_id': ObjectId('573a13a1f29313caabd08345'), 'title': 'The Tigger Movie'},
#  {'_id': ObjectId('573a13a1f29313caabd0871d'), 'title': 'Dead or Alive'},
#  {'_id': ObjectId('573a13a1f29313caabd08d89'), 'title': 'Brother'},
#  {'_id': ObjectId('573a13a1f29313caabd095a1'),
#   'title': 'Screams of Blasphemy'},
#  {'_id': ObjectId('573a13a2f29313caabd09d85'),
#   'title': 'A Pool Without Water'},
#  {'_id': ObjectId('573a13a2f29313caabd0a0a8'), 'title': 'Zero no shèten'},
#  {'_id': ObjectId('573a13a2f29313caabd0a214'),
#   'title': 'Edogawa Ranpo ryèki-kan: Yaneura no sanposha'},
#  {'_id': ObjectId('573a13a2f29313caabd0a3c5'), 'title': 'Greedy Guts'},
#  {'_id': ObjectId('573a13a2f29313caabd0a683'), 'title': 'First Love'},
#  {'_id': ObjectId('573a13a2f29313caabd0ab60'), 'title': 'Ring'},
#  {'_id': ObjectId('573a13a2f29313caabd0b4a7'), 'title': 'Pola X'},
#  {'_id': ObjectId('573a13a2f29313caabd0bcb5'), 'title': 'Audition'},
#  {'_id': ObjectId('573a13a2f29313caabd0beb8'), 'title': 'Ring 0: Birthday'},
#  {'_id': ObjectId('573a13a3f29313caabd0cc92'), 'title': 'Trouble Every Day'},
#  {'_id': ObjectId('573a13a3f29313caabd0cd93'), 'title': 'Monday'},
#  {'_id': ObjectId('573a13a3f29313caabd0d0a9'), 'title': 'La Ciènaga'},
#  {'_id': ObjectId('573a13a3f29313caabd0d271'), 'title': 'Under the Sand'},
#  {'_id': ObjectId('573a13a3f29313caabd0db23'), 'title': 'The Doe Boy'},
#  {'_id': ObjectId('573a13a3f29313caabd0db33'), 'title': 'Willow and Wind'},
#  {'_id': ObjectId('573a13a3f29313caabd0dda4'), 'title': 'Eureka'},
#  {'_id': ObjectId('573a13a3f29313caabd0df51'), 'title': 'Yi Yi'},
#  {'_id': ObjectId('573a13a3f29313caabd0e371'), 'title': 'Spirited Away'},
#  {'_id': ObjectId('573a13a3f29313caabd0e698'), 'title': 'Blackboards'},
#  {'_id': ObjectId('573a13a3f29313caabd0e6e1'), 'title': 'Yi Yi'},
#  {'_id': ObjectId('573a13a3f29313caabd0e8eb'), 'title': 'Rollerball'},
#  {'_id': ObjectId('573a13a3f29313caabd0eba5'), 'title': 'Peppermint Candy'},
#  {'_id': ObjectId('573a13a4f29313caabd1083a'),
#   'title': 'Godzilla vs. Megaguirus'},
#  {'_id': ObjectId('573a13a4f29313caabd1163c'), 'title': 'Platform'},
#  {'_id': ObjectId('573a13a4f29313caabd1181b'), 'title': 'Seance'},
#  {'_id': ObjectId('573a13a4f29313caabd1185b'), 'title': "The Monkey's Mask"},
#  {'_id': ObjectId('573a13a4f29313caabd11a92'),
#   'title': 'Gojo reisenki: Gojoe'},
#  {'_id': ObjectId('573a13a5f29313caabd13247'), 'title': 'Battle Royale'},
#  {'_id': ObjectId('573a13a5f29313caabd132bd'), 'title': 'Coquille'},
#  {'_id': ObjectId('573a13a5f29313caabd134e7'), 'title': 'Spy Game'},
#  {'_id': ObjectId('573a13a5f29313caabd13550'), 'title': 'Wild Zero'},
#  {'_id': ObjectId('573a13a5f29313caabd13607'), 'title': 'Avalon'},
#  {'_id': ObjectId('573a13a5f29313caabd137eb'), 'title': 'Party 7'},
#  {'_id': ObjectId('573a13a5f29313caabd13fb5'), 'title': 'Ritual'},
#  {'_id': ObjectId('573a13a5f29313caabd14e36'), 'title': "It's All About Love"},
#  {'_id': ObjectId('573a13a5f29313caabd1540d'),
#   'title': 'Blood: The Last Vampire'},
#  {'_id': ObjectId('573a13a5f29313caabd1542e'),
#   'title': 'Cowboy Bebop: The Movie'},
#  {'_id': ObjectId('573a13a5f29313caabd15604'), 'title': 'Versus'},
#  {'_id': ObjectId('573a13a5f29313caabd16012'), 'title': 'Distance'},
#  {'_id': ObjectId('573a13a5f29313caabd1603c'), 'title': 'Galaxy Express 999'},
#  {'_id': ObjectId('573a13a5f29313caabd1628a'), 'title': 'FLCL'},
#  {'_id': ObjectId('573a13a5f29313caabd162a3'),
#   'title': 'Godzilla, Mothra and King Ghidorah: Giant Monsters All-Out Attack'},
#  {'_id': ObjectId('573a13a6f29313caabd165c1'),
#   'title': 'A Fugitive from the Past'},
#  {'_id': ObjectId('573a13a6f29313caabd16ed7'), 'title': 'Audition'},
#  {'_id': ObjectId('573a13a6f29313caabd17258'), 'title': 'The Eel'},
#  {'_id': ObjectId('573a13a6f29313caabd175f2'), 'title': 'Seance'},
#  {'_id': ObjectId('573a13a6f29313caabd178b5'),
#   'title': 'Dead or Alive 2: Tèbèsha'},
#  {'_id': ObjectId('573a13a6f29313caabd17c1d'), 'title': 'Pistol Opera'},
#  {'_id': ObjectId('573a13a6f29313caabd17e3b'), 'title': 'Akira'},
#  {'_id': ObjectId('573a13a6f29313caabd17f60'), 'title': 'Pulse'},
#  {'_id': ObjectId('573a13a6f29313caabd1844e'), 'title': 'Pulse'},
#  {'_id': ObjectId('573a13a6f29313caabd187f7'),
#   'title': 'Warm Water Under a Red Bridge'},
#  {'_id': ObjectId('573a13a6f29313caabd18ca6'), 'title': 'Visitor Q'},
#  {'_id': ObjectId('573a13a6f29313caabd18dd9'), 'title': 'Hush!'},
#  {'_id': ObjectId('573a13a6f29313caabd18de5'), 'title': 'Hollywood Hong-Kong'},
#  {'_id': ObjectId('573a13a6f29313caabd1907d'), 'title': 'Millennium Actress'},
#  {'_id': ObjectId('573a13a6f29313caabd19132'), 'title': 'Visitor Q'},
#  {'_id': ObjectId('573a13a6f29313caabd19712'), 'title': 'Delbaran'},
#  {'_id': ObjectId('573a13a6f29313caabd1985f'), 'title': 'Metropolis'},
#  {'_id': ObjectId('573a13a6f29313caabd19980'), 'title': 'The Touch'},
#  {'_id': ObjectId('573a13a7f29313caabd19f29'), 'title': 'One Fine Spring Day'},
#  {'_id': ObjectId('573a13a7f29313caabd19fd4'), 'title': 'Chaos'},
#  {'_id': ObjectId('573a13a7f29313caabd1a274'), 'title': 'Ichi the Killer'},
#  {'_id': ObjectId('573a13a7f29313caabd1a8a1'),
#   'title': 'All About Lily Chou-Chou'},
#  {'_id': ObjectId('573a13a7f29313caabd1a90b'), 'title': 'Drive'},
#  {'_id': ObjectId('573a13a7f29313caabd1a933'), 'title': 'Harmful Insect'},
#  {'_id': ObjectId('573a13a7f29313caabd1a947'), 'title': 'Harmful Insect'},
#  {'_id': ObjectId('573a13a7f29313caabd1a9a7'), 'title': 'The Last Unicorn'},
#  {'_id': ObjectId('573a13a7f29313caabd1aa03'), 'title': 'The Ring'},
#  {'_id': ObjectId('573a13a7f29313caabd1ae15'), 'title': 'Waterboys'},
#  {'_id': ObjectId('573a13a7f29313caabd1b0e8'), 'title': 'Go'},
#  {'_id': ObjectId('573a13a7f29313caabd1b622'), 'title': 'Ghost in the Shell'},
#  {'_id': ObjectId('573a13a7f29313caabd1b635'),
#   'title': 'Grave of the Fireflies'},
#  {'_id': ObjectId('573a13a7f29313caabd1b667'), 'title': 'Man on the Train'},
#  {'_id': ObjectId('573a13a7f29313caabd1bee8'),
#   'title': 'Armitage: Dual Matrix'},
#  {'_id': ObjectId('573a13a7f29313caabd1bf3d'), 'title': 'Blues Harp'},
#  {'_id': ObjectId('573a13a7f29313caabd1c118'),
#   'title': 'The Happiness of the Katakuris'},
#  {'_id': ObjectId('573a13a8f29313caabd1c933'), 'title': 'Princess Arete'},
#  {'_id': ObjectId('573a13a8f29313caabd1cbae'), 'title': 'All About Our House'},
#  {'_id': ObjectId('573a13a8f29313caabd1d03e'), 'title': 'Dark Water'},
#  {'_id': ObjectId('573a13a8f29313caabd1d213'), 'title': 'Rènin-gai'},
#  {'_id': ObjectId('573a13a8f29313caabd1d3a9'), 'title': 'Blue Spring'},
#  {'_id': ObjectId('573a13a8f29313caabd1d405'), 'title': 'Blue Spring'},
#  {'_id': ObjectId('573a13a8f29313caabd1d6f8'), 'title': 'The Princess Blade'},
#  {'_id': ObjectId('573a13a8f29313caabd1e13c'), 'title': 'Suicide Club'},
#  {'_id': ObjectId('573a13a9f29313caabd1ef51'), 'title': 'Graveyard of Honor'},
#  {'_id': ObjectId('573a13a9f29313caabd1f011'), 'title': 'The Sea Is Watching'},
#  {'_id': ObjectId('573a13a9f29313caabd1f48a'), 'title': 'Unknown Pleasures'},
#  {'_id': ObjectId('573a13a9f29313caabd1f4ac'), 'title': 'Russian Ark'},
#  {'_id': ObjectId('573a13a9f29313caabd1f73d'), 'title': 'Fear and Trembling'},
#  {'_id': ObjectId('573a13a9f29313caabd1f811'), 'title': 'A2'},
#  {'_id': ObjectId('573a13aaf29313caabd21182'),
#   'title': 'Lara Croft Tomb Raider: The Cradle of Life'},
#  {'_id': ObjectId('573a13aaf29313caabd21193'), 'title': 'The Last Samurai'},
#  {'_id': ObjectId('573a13aaf29313caabd21596'), 'title': 'Blue'},
#  {'_id': ObjectId('573a13aaf29313caabd21d3f'), 'title': 'September 11'},
#  {'_id': ObjectId('573a13aaf29313caabd21d5c'), 'title': 'The Animatrix'},
#  {'_id': ObjectId('573a13aaf29313caabd22246'), 'title': 'The Brown Bunny'},
#  {'_id': ObjectId('573a13aaf29313caabd222c9'), 'title': 'Dolls'},
#  {'_id': ObjectId('573a13aaf29313caabd222cb'), 'title': 'September 11'},
#  {'_id': ObjectId('573a13aaf29313caabd22548'), 'title': 'A Snake of June'},
#  {'_id': ObjectId('573a13aaf29313caabd22c05'), 'title': 'Woman of Water'},
#  {'_id': ObjectId('573a13aaf29313caabd230a2'), 'title': 'The Best of Times'},
#  {'_id': ObjectId('573a13aaf29313caabd23604'), 'title': 'Lost in Translation'},
#  {'_id': ObjectId('573a13abf29313caabd2431c'), 'title': 'Battle Royale II'},
#  {'_id': ObjectId('573a13abf29313caabd24627'), 'title': 'Returner'},
#  {'_id': ObjectId('573a13abf29313caabd25cbc'),
#   'title': 'Last Life in the Universe'},
#  {'_id': ObjectId('573a13abf29313caabd262ca'),
#   'title': "Howl's Moving Castle"},
#  {'_id': ObjectId('573a13abf29313caabd2633e'),
#   'title': 'Ghost in the Shell 2: Innocence'},
#  {'_id': ObjectId('573a13abf29313caabd26495'), 'title': 'The Cat Returns'},
#  {'_id': ObjectId('573a13acf29313caabd2669f'), 'title': 'Steamboy'},
#  {'_id': ObjectId('573a13acf29313caabd272ee'), 'title': 'Mount Head'},
#  {'_id': ObjectId('573a13acf29313caabd27494'),
#   'title': 'The Twilight Samurai'},
#  {'_id': ObjectId('573a13acf29313caabd283d7'),
#   'title': 'Onmyoji: The Yin Yang Master'},
#  {'_id': ObjectId('573a13acf29313caabd28e2a'), 'title': 'Blessing Bell'},
#  {'_id': ObjectId('573a13acf29313caabd28fde'), 'title': 'Blessing Bell'},
#  {'_id': ObjectId('573a13acf29313caabd29261'),
#   'title': 'When the Last Sword is Drawn'},
#  {'_id': ObjectId('573a13adf29313caabd299d4'), 'title': 'Gozu'},
#  {'_id': ObjectId('573a13adf29313caabd29c8b'), 'title': '2LDK'},
#  {'_id': ObjectId('573a13adf29313caabd29ca7'), 'title': 'Aragami'},
#  {'_id': ObjectId('573a13adf29313caabd29f05'), 'title': 'Shara'},
#  {'_id': ObjectId('573a13adf29313caabd29faa'), 'title': 'Bright Future'},
#  {'_id': ObjectId('573a13adf29313caabd29fc5'),
#   'title': 'The Blind Swordsman: Zatoichi'},
#  {'_id': ObjectId('573a13adf29313caabd2a0cf'), 'title': 'Dawn of the Dead'},
#  {'_id': ObjectId('573a13adf29313caabd2a408'), 'title': 'Ju-on: The Grudge'},
#  {'_id': ObjectId('573a13adf29313caabd2a83f'), 'title': 'Moon Child'},
#  {'_id': ObjectId('573a13adf29313caabd2b146'), 'title': 'Ju-on: The Grudge 2'},
#  {'_id': ObjectId('573a13adf29313caabd2b446'),
#   'title': 'The Heart Is Deceitful Above All Things'},
#  {'_id': ObjectId('573a13adf29313caabd2b4c7'), 'title': 'Osama'},
#  {'_id': ObjectId('573a13adf29313caabd2b9b7'), 'title': '9 Souls'},
#  {'_id': ObjectId('573a13aef29313caabd2c8d9'),
#   'title': 'Tamala 2010: A Punk Cat in Space'},
#  {'_id': ObjectId('573a13aef29313caabd2c8ee'), 'title': 'The Tesseract'},
#  {'_id': ObjectId('573a13aef29313caabd2cc86'), 'title': 'Innocence'},
#  {'_id': ObjectId('573a13aef29313caabd2cdcb'), 'title': 'Astro Boy'},
#  {'_id': ObjectId('573a13aef29313caabd2d378'), 'title': 'Izo'},
#  {'_id': ObjectId('573a13aef29313caabd2d76e'), 'title': 'Izo'},
#  {'_id': ObjectId('573a13aef29313caabd2d9ca'), 'title': 'Yukikaze'},
#  {'_id': ObjectId('573a13aef29313caabd2db99'),
#   'title': 'Coffee and Cigarettes'},
#  {'_id': ObjectId('573a13aef29313caabd2dd0d'), 'title': 'Vibrator'},
#  {'_id': ObjectId('573a13aef29313caabd2e3b9'),
#   'title': 'The Place Promised in Our Early Days'},
#  {'_id': ObjectId('573a13aef29313caabd2e693'), 'title': 'Junkers Come Here'},
#  {'_id': ObjectId('573a13aef29313caabd2e965'),
#   'title': 'Nasu: Summer in Andalusia'},
#  {'_id': ObjectId('573a13aef29313caabd2ee12'),
#   'title': 'Pokèmon: The First Movie - Mewtwo Strikes Back'},
#  {'_id': ObjectId('573a13aef29313caabd2efab'), 'title': 'Silent Hill'},
#  {'_id': ObjectId('573a13aff29313caabd2f0a8'), 'title': 'Azumi'},
#  {'_id': ObjectId('573a13aff29313caabd2f392'), 'title': 'Cat Soup'},
#  {'_id': ObjectId('573a13aff29313caabd2fe7c'), 'title': 'Tokyo Godfathers'},
#  {'_id': ObjectId('573a13aff29313caabd2fee1'), 'title': 'Zebraman'},
#  {'_id': ObjectId('573a13aff29313caabd308ef'), 'title': 'The Grudge'},
#  {'_id': ObjectId('573a13aff29313caabd30f6a'), 'title': 'Valley of Flowers'},
#  {'_id': ObjectId('573a13aff29313caabd3225f'),
#   'title': 'Godzilla: Final Wars'},
#  {'_id': ObjectId('573a13aff29313caabd3270e'), 'title': 'Exiles'},
#  {'_id': ObjectId('573a13aff29313caabd32849'),
#   'title': 'Quill: The Life of a Guide Dog'},
#  {'_id': ObjectId('573a13b0f29313caabd33400'), 'title': 'Doppelganger'},
#  {'_id': ObjectId('573a13b0f29313caabd33413'), 'title': 'Doppelganger'},
#  {'_id': ObjectId('573a13b0f29313caabd342a8'), 'title': 'Hana and Alice'},
#  {'_id': ObjectId('573a13b0f29313caabd345ad'), 'title': 'Nobody Knows'},
#  {'_id': ObjectId('573a13b0f29313caabd34a47'), 'title': "Satan's Sword"},
#  {'_id': ObjectId('573a13b0f29313caabd352b9'),
#   'title': "The World's Fastest Indian"},
#  {'_id': ObjectId('573a13b0f29313caabd3549d'), 'title': 'Cafè Lumière'},
#  {'_id': ObjectId('573a13b1f29313caabd3598f'), 'title': 'The Taste of Tea'},
#  {'_id': ObjectId('573a13b1f29313caabd36257'), 'title': 'Kamikaze Girls'},
#  {'_id': ObjectId('573a13b1f29313caabd364e3'),
#   'title': 'Josee, the Tiger and the Fish'},
#  {'_id': ObjectId('573a13b1f29313caabd36632'), 'title': 'Vital'},
#  {'_id': ObjectId('573a13b1f29313caabd36e1e'), 'title': 'Supervolcano'},
#  {'_id': ObjectId('573a13b1f29313caabd36eb3'), 'title': 'Blood and Bones'},
#  {'_id': ObjectId('573a13b1f29313caabd37187'), 'title': 'Tony Takitani'},
#  {'_id': ObjectId('573a13b1f29313caabd37190'), 'title': 'Three... Extremes'},
#  {'_id': ObjectId('573a13b1f29313caabd3749d'), 'title': 'Control'},
#  {'_id': ObjectId('573a13b1f29313caabd37aa0'), 'title': 'Marie Antoinette'},
#  {'_id': ObjectId('573a13b1f29313caabd37bd3'), 'title': 'Rampo Noir'},
#  {'_id': ObjectId('573a13b1f29313caabd37c5f'), 'title': 'The World'},
#  {'_id': ObjectId('573a13b1f29313caabd37f06'), 'title': '3-Iron'},
#  {'_id': ObjectId('573a13b1f29313caabd38071'), 'title': 'Joyeux Noel'},
#  {'_id': ObjectId('573a13b1f29313caabd38139'),
#   'title': 'Crying Out Love in the Center of the World'},
#  {'_id': ObjectId('573a13b2f29313caabd385c9'), 'title': 'Red Cliff'},
#  {'_id': ObjectId('573a13b2f29313caabd385df'), 'title': 'The Great Yokai War'},
#  {'_id': ObjectId('573a13b2f29313caabd38c8d'), 'title': 'Ornamental Hairpin'},
#  {'_id': ObjectId('573a13b2f29313caabd39754'), 'title': 'Hell'},
#  {'_id': ObjectId('573a13b2f29313caabd398d4'), 'title': 'Survive Style 5+'},
#  {'_id': ObjectId('573a13b2f29313caabd39a69'), 'title': 'G@me'},
#  {'_id': ObjectId('573a13b2f29313caabd3a2fb'),
#   'title': 'Good Night, and Good Luck.'},
#  {'_id': ObjectId('573a13b2f29313caabd3a2fd'), 'title': 'The Grudge 2'},
#  {'_id': ObjectId('573a13b2f29313caabd3ac24'), 'title': 'The White Diamond'},
#  {'_id': ObjectId('573a13b3f29313caabd3b262'),
#   'title': 'Riding Alone for Thousands of Miles'},
#  {'_id': ObjectId('573a13b3f29313caabd3c269'), 'title': 'Princess Raccoon'},
#  {'_id': ObjectId('573a13b3f29313caabd3c4af'), 'title': 'The Hidden Blade'},
#  {'_id': ObjectId('573a13b3f29313caabd3c4b9'), 'title': 'Be with You'},
#  {'_id': ObjectId('573a13b3f29313caabd3c853'), 'title': 'Loft'},
#  {'_id': ObjectId('573a13b3f29313caabd3ca2a'), 'title': 'Princess Raccoon'},
#  {'_id': ObjectId('573a13b3f29313caabd3d035'), 'title': 'You, the Living'},
#  {'_id': ObjectId('573a13b3f29313caabd3d2ba'),
#   'title': 'Scott Pilgrim vs. the World'},
#  {'_id': ObjectId('573a13b3f29313caabd3e8b6'),
#   'title': 'Funky Forest: The First Contact'},
#  {'_id': ObjectId('573a13b3f29313caabd3e969'), 'title': 'Mind Game'},
#  {'_id': ObjectId('573a13b4f29313caabd3fa09'), 'title': 'The Bow'},
#  {'_id': ObjectId('573a13b4f29313caabd3fb5c'), 'title': 'About Love'},
#  {'_id': ObjectId('573a13b4f29313caabd3fb75'), 'title': 'Bashing'},
#  {'_id': ObjectId('573a13b4f29313caabd3fb8f'), 'title': "Who's Camus Anyway"},
#  {'_id': ObjectId('573a13b4f29313caabd4065d'), 'title': 'Ashura-jè no hitomi'},
#  {'_id': ObjectId('573a13b4f29313caabd40902'), 'title': 'The Bow'},
#  {'_id': ObjectId('573a13b4f29313caabd40a60'), 'title': 'Hanging Garden'},
#  {'_id': ObjectId('573a13b4f29313caabd40e18'), 'title': 'A Stranger of Mine'},
#  {'_id': ObjectId('573a13b4f29313caabd41639'), 'title': 'Hana'},
#  {'_id': ObjectId('573a13b5f29313caabd42770'), 'title': 'Way of Blue Sky'},
#  {'_id': ObjectId('573a13b5f29313caabd42812'), 'title': 'Linda Linda Linda'},
#  {'_id': ObjectId('573a13b5f29313caabd42855'),
#   'title': "Noriko's Dinner Table"},
#  {'_id': ObjectId('573a13b5f29313caabd428a5'),
#   'title': 'Yaji and Kita: The Midnight Pilgrims'},
#  {'_id': ObjectId('573a13b5f29313caabd43384'), 'title': 'Nana'},
#  {'_id': ObjectId('573a13b5f29313caabd4380e'), 'title': 'Japan Sinks'},
#  {'_id': ObjectId('573a13b5f29313caabd44205'),
#   'title': 'Shinobi: Heart Under Blade'},
#  {'_id': ObjectId('573a13b5f29313caabd44232'), 'title': 'Tokyo Tower'},
#  {'_id': ObjectId('573a13b5f29313caabd449e9'),
#   'title': 'Shinobi: Heart Under Blade'},
#  {'_id': ObjectId('573a13b5f29313caabd44aae'), 'title': "Takeshis'"},
#  {'_id': ObjectId('573a13b5f29313caabd451cc'), 'title': 'One Missed Call'},
#  {'_id': ObjectId('573a13b6f29313caabd45b1c'), 'title': 'Bandage'},
#  {'_id': ObjectId('573a13b6f29313caabd45d38'), 'title': 'Kamome Diner'},
#  {'_id': ObjectId('573a13b6f29313caabd45f57'), 'title': 'Love and Honour'},
#  {'_id': ObjectId('573a13b6f29313caabd465e7'),
#   'title': 'Fullmetal Alchemist the Movie: Conqueror of Shamballa'},
#  {'_id': ObjectId('573a13b6f29313caabd467f5'),
#   'title': 'Battle of the Warriors'},
#  {'_id': ObjectId('573a13b6f29313caabd4733c'),
#   'title': 'Always - Sunset on Third Street'},
#  {'_id': ObjectId('573a13b6f29313caabd47c87'), 'title': 'Haze'},
#  {'_id': ObjectId('573a13b6f29313caabd481b5'), 'title': 'Strange Circus'},
#  {'_id': ObjectId('573a13b6f29313caabd48381'),
#   'title': 'Origin: Spirits of the Past'},
#  {'_id': ObjectId('573a13b6f29313caabd4896b'), 'title': 'Silk'},
#  {'_id': ObjectId('573a13b6f29313caabd48af3'), 'title': 'Hellsing Ultimate'},
#  {'_id': ObjectId('573a13b6f29313caabd48c52'), 'title': 'Tales from Earthsea'},
#  {'_id': ObjectId('573a13b7f29313caabd4949b'),
#   'title': 'Big Bang Love, Juvenile A'},
#  {'_id': ObjectId('573a13b7f29313caabd4952a'), 'title': 'Time'},
#  {'_id': ObjectId('573a13b7f29313caabd496bb'), 'title': 'Stormy Night'},
# ...
#  {'_id': ObjectId('573a13c4f29313caabd6d3ad'),
#   'title': 'Surviving Life (Theory and Practice)'},
#  {'_id': ObjectId('573a13c4f29313caabd6dec7'),
#   'title': 'The House of Small Cubes'},
#  {'_id': ObjectId('573a13c5f29313caabd6eba9'), 'title': 'Air Doll'},
#  {'_id': ObjectId('573a13c5f29313caabd70bce'), 'title': 'Oppai Volleyball'},
#  {'_id': ObjectId('573a13c5f29313caabd70e7c'),
#   'title': 'I Give My First Love to You'},
#  {'_id': ObjectId('573a13c6f29313caabd7177d'), 'title': 'Symbol'},
#  {'_id': ObjectId('573a13c6f29313caabd7259e'), 'title': 'Somewhere'},
#  {'_id': ObjectId('573a13c6f29313caabd72c00'),
#   'title': 'Vampire Girl vs. Frankenstein Girl'},
#  {'_id': ObjectId('573a13c6f29313caabd72d86'), 'title': 'A Pierrot'},
#  {'_id': ObjectId('573a13c6f29313caabd736c7'), 'title': '13 Assassins'},
#  {'_id': ObjectId('573a13c7f29313caabd744a9'), 'title': 'Hamlet'},
#  {'_id': ObjectId('573a13c7f29313caabd7540f'), 'title': 'Outrage'},
#  {'_id': ObjectId('573a13c7f29313caabd75a2c'),
#   'title': 'Hottarake no shima - Haruka to maho no kagami'},
#  {'_id': ObjectId('573a13c7f29313caabd7608d'), 'title': 'Summer Wars'},
#  {'_id': ObjectId('573a13c7f29313caabd76400'),
#   'title': 'Space Battleship Yamato'},
#  {'_id': ObjectId('573a13c7f29313caabd7668a'),
#   'title': 'Supermen of Malegaon'},
#  {'_id': ObjectId('573a13c8f29313caabd76b94'), 'title': 'Redline'},
#  {'_id': ObjectId('573a13c8f29313caabd76d76'),
#   'title': 'One Piece: Strong World'},
#  {'_id': ObjectId('573a13c8f29313caabd774f4'), 'title': 'Parade'},
#  {'_id': ObjectId('573a13c8f29313caabd785c8'), 'title': 'Caterpillar'},
#  {'_id': ObjectId('573a13c9f29313caabd7947c'),
#   'title': 'Tales of Vesperia: The First Strike'},
#  {'_id': ObjectId('573a13c9f29313caabd79bd8'), 'title': 'Gantz'},
#  {'_id': ObjectId('573a13c9f29313caabd7acf8'), 'title': 'Make Believe'},
#  {'_id': ObjectId('573a13c9f29313caabd7b435'), 'title': 'Villain'},
#  {'_id': ObjectId('573a13c9f29313caabd7b47e'), 'title': 'Our Brief Eternity'},
#  {'_id': ObjectId('573a13caf29313caabd7c264'), 'title': 'Our Brief Eternity'},
#  {'_id': ObjectId('573a13caf29313caabd7c424'),
#   'title': 'Saigo no Chèshingura'},
#  {'_id': ObjectId('573a13caf29313caabd7d6da'),
#   'title': 'The Secret World of Arrietty'},
#  {'_id': ObjectId('573a13caf29313caabd7d7d7'),
#   'title': 'The Secret World of Arrietty'},
#  {'_id': ObjectId('573a13caf29313caabd7ea03'), 'title': 'Peak: The Rescuers'},
#  {'_id': ObjectId('573a13cbf29313caabd7ebd3'), 'title': 'Beck'},
#  {'_id': ObjectId('573a13cbf29313caabd7f021'), 'title': 'Confessions'},
#  {'_id': ObjectId('573a13cbf29313caabd7f33b'), 'title': 'Take This Waltz'},
#  {'_id': ObjectId('573a13cbf29313caabd7fb72'), 'title': 'Safe House'},
#  {'_id': ObjectId('573a13cbf29313caabd805b6'), 'title': "Tomorrow's Joe"},
#  {'_id': ObjectId('573a13cbf29313caabd8064a'),
#   'title': 'Sword of Desperation'},
#  {'_id': ObjectId('573a13cbf29313caabd80f5b'), 'title': 'Time Traveller'},
#  {'_id': ObjectId('573a13ccf29313caabd81bc0'), 'title': 'Vampire'},
#  {'_id': ObjectId('573a13ccf29313caabd82438'), 'title': 'Cold Fish'},
#  {'_id': ObjectId('573a13ccf29313caabd82d23'), 'title': 'Postcard'},
#  {'_id': ObjectId('573a13ccf29313caabd836d1'), 'title': 'I Wish'},
#  {'_id': ObjectId('573a13ccf29313caabd8373e'), 'title': 'Kick-Ass 2'},
#  {'_id': ObjectId('573a13cdf29313caabd83c08'), 'title': 'Ghost'},
#  {'_id': ObjectId('573a13cdf29313caabd850cc'), 'title': 'Bunny Drop'},
#  {'_id': ObjectId('573a13cdf29313caabd85492'), 'title': 'The Floating Castle'},
#  {'_id': ObjectId('573a13cdf29313caabd8577e'), 'title': 'Colourful'},
#  {'_id': ObjectId('573a13cef29313caabd8638a'),
#   'title': 'Pokèmon: Zoroark: Master of Illusions'},
#  {'_id': ObjectId('573a13cef29313caabd863a0'), 'title': 'King of Thorn'},
#  {'_id': ObjectId('573a13cef29313caabd863b1'),
#   'title': 'Pokèmon: Zoroark: Master of Illusions'},
#  {'_id': ObjectId('573a13cef29313caabd871a8'),
#   'title': 'Sketches of Kaitan City'},
#  {'_id': ObjectId('573a13cef29313caabd873a2'), 'title': 'Ghost'},
#  {'_id': ObjectId('573a13cef29313caabd878dc'),
#   'title': 'Dragon Age: Dawn of the Seeker'},
#  {'_id': ObjectId('573a13cef29313caabd87fd1'), 'title': 'Time of Eve'},
#  {'_id': ObjectId('573a13cef29313caabd8871f'), 'title': 'Tormented'},
#  {'_id': ObjectId('573a13cff29313caabd88a07'), 'title': 'Beyond Outrage'},
#  {'_id': ObjectId('573a13cff29313caabd8902f'),
#   'title': 'Hara-Kiri: Death of a Samurai'},
#  {'_id': ObjectId('573a13cff29313caabd89072'),
#   'title': 'Animation Runner Kuromi'},
#  {'_id': ObjectId('573a13cff29313caabd8962d'), 'title': 'Hospitalitè'},
#  {'_id': ObjectId('573a13cff29313caabd89d1f'), 'title': 'PressPausePlay'},
#  {'_id': ObjectId('573a13cff29313caabd8a3d2'), 'title': 'Guilty of Romance'},
#  {'_id': ObjectId('573a13cff29313caabd8a8ea'), 'title': 'Saya-zamurai'},
#  {'_id': ObjectId('573a13d0f29313caabd8c578'),
#   'title': 'Fullmetal Alchemist: The Sacred Star of Milos'},
#  {'_id': ObjectId('573a13d0f29313caabd8ce76'), 'title': 'Tèkyè kèen'},
#  {'_id': ObjectId('573a13d1f29313caabd8dfa1'), 'title': 'Tokyo Family'},
#  {'_id': ObjectId('573a13d1f29313caabd8e11a'),
#   'title': 'From Up on Poppy Hill'},
#  {'_id': ObjectId('573a13d1f29313caabd8e40d'),
#   'title': 'From Up on Poppy Hill'},
#  {'_id': ObjectId('573a13d1f29313caabd8e9a2'), 'title': 'Girl Model'},
#  {'_id': ObjectId('573a13d1f29313caabd8fa22'),
#   'title': 'Chronicle of My Mother'},
#  {'_id': ObjectId('573a13d2f29313caabd910f3'),
#   'title': 'Sushi: The Global Catch'},
#  {'_id': ObjectId('573a13d2f29313caabd91141'),
#   'title': 'Tenchi: The Samurai Astronomer'},
#  {'_id': ObjectId('573a13d2f29313caabd916db'), 'title': 'Journey to Agartha'},
#  {'_id': ObjectId('573a13d2f29313caabd91bc4'), 'title': 'Kotoko'},
#  {'_id': ObjectId('573a13d2f29313caabd91cc9'),
#   'title': 'Like Someone in Love'},
#  {'_id': ObjectId('573a13d2f29313caabd92344'), 'title': 'Life Back Then'},
#  {'_id': ObjectId('573a13d2f29313caabd92a21'), 'title': 'A Letter to Momo'},
#  {'_id': ObjectId('573a13d2f29313caabd93b30'), 'title': 'Thermae Romae'},
#  {'_id': ObjectId('573a13d2f29313caabd93b81'),
#   'title': 'The Woodsman and the Rain'},
#  {'_id': ObjectId('573a13d3f29313caabd953f6'), 'title': 'About the Pink Sky'},
#  {'_id': ObjectId('573a13d3f29313caabd95568'), 'title': 'Ace Attorney'},
#  {'_id': ObjectId('573a13d3f29313caabd95b57'), 'title': 'Himizu'},
#  {'_id': ObjectId('573a13d3f29313caabd964c2'), 'title': 'Hayabusa'},
#  {'_id': ObjectId('573a13d3f29313caabd970ee'),
#   'title': 'Isoroku Yamamoto, the Commander-in-Chief of the Combined Fleet'},
#  {'_id': ObjectId('573a13d4f29313caabd99c3e'), 'title': 'Rurouni Kenshin'},
#  {'_id': ObjectId('573a13d5f29313caabd9b905'), 'title': 'Jellyfish Eyes'},
#  {'_id': ObjectId('573a13d5f29313caabd9c1bc'), 'title': 'The Wind Rises'},
#  {'_id': ObjectId('573a13d5f29313caabd9d89c'), 'title': 'Penance'},
#  {'_id': ObjectId('573a13d5f29313caabd9dcd9'),
#   'title': 'Mardock Scramble: The Second Combustion'},
#  {'_id': ObjectId('573a13d6f29313caabd9e354'), 'title': 'Planet of Snail'},
#  {'_id': ObjectId('573a13d6f29313caabd9f7a8'), 'title': '009 Re: Cyborg'},
#  {'_id': ObjectId('573a13d6f29313caabd9f7e5'), 'title': 'Key of Life'},
#  {'_id': ObjectId('573a13d6f29313caabd9fae9'), 'title': 'China Heavyweight'},
#  {'_id': ObjectId('573a13d6f29313caabd9feb4'),
#   'title': 'Starship Troopers: Invasion'},
#  {'_id': ObjectId('573a13d7f29313caabda1303'), 'title': 'Emperor'},
#  {'_id': ObjectId('573a13d7f29313caabda2690'), 'title': 'The House I Live In'},
#  {'_id': ObjectId('573a13d7f29313caabda2af1'), 'title': 'The Bling Ring'},
#  {'_id': ObjectId('573a13d7f29313caabda3153'),
#   'title': 'Mass Effect: Paragon Lost'},
#  {'_id': ObjectId('573a13d7f29313caabda315f'), 'title': 'Wolf Children'},
#  {'_id': ObjectId('573a13d7f29313caabda382c'), 'title': 'Helter Skelter'},
#  {'_id': ObjectId('573a13d7f29313caabda3e90'), 'title': 'A Story of Yonosuke'},
#  {'_id': ObjectId('573a13d8f29313caabda6891'), 'title': 'Chainsaw Maid'},
#  {'_id': ObjectId('573a13d8f29313caabda7264'), 'title': 'The Brain Man'},
#  {'_id': ObjectId('573a13d8f29313caabda739d'),
#   'title': 'Berserk: The Golden Age Arc I - The Egg of the King'},
#  {'_id': ObjectId('573a13d8f29313caabda7481'),
#   'title': "Pecoross' Mother and Her Days"},
#  {'_id': ObjectId('573a13d9f29313caabda95b1'),
#   'title': 'The Kiyosu Conference'},
#  {'_id': ObjectId('573a13d9f29313caabda973b'), 'title': 'Rentaneko'},
#  {'_id': ObjectId('573a13d9f29313caabdaa33d'),
#   'title': 'Dragon Age: Dawn of the Seeker'},
#  {'_id': ObjectId('573a13d9f29313caabdaa68e'),
#   'title': 'Dragon Ball Z: Battle of Gods'},
#  {'_id': ObjectId('573a13d9f29313caabdaad14'), 'title': 'Inori'},
#  {'_id': ObjectId('573a13daf29313caabdab5a0'), 'title': 'Real'},
#  {'_id': ObjectId('573a13daf29313caabdab7aa'), 'title': 'Platinum Data'},
#  {'_id': ObjectId('573a13daf29313caabdab7be'),
#   'title': 'The Samurai That Night'},
#  {'_id': ObjectId('573a13daf29313caabdabea7'),
#   'title': 'Road to Ninja: Naruto the Movie'},
#  {'_id': ObjectId('573a13daf29313caabdabead'), 'title': 'The Wind Rises'},
#  {'_id': ObjectId('573a13daf29313caabdac1e5'), 'title': 'Lesson of the Evil'},
#  {'_id': ObjectId('573a13daf29313caabdad09d'),
#   'title': 'Aim High in Creation'},
#  {'_id': ObjectId('573a13daf29313caabdad25f'), 'title': 'The Real Miyagi'},
#  {'_id': ObjectId('573a13daf29313caabdad38a'), 'title': 'The Great Passage'},
#  {'_id': ObjectId('573a13dbf29313caabdae31d'), 'title': 'Asura'},
#  {'_id': ObjectId('573a13dbf29313caabdae625'),
#   'title': 'Like Father, Like Son'},
#  {'_id': ObjectId('573a13dbf29313caabdaf598'), 'title': 'Unforgiven'},
#  {'_id': ObjectId('573a13dbf29313caabdaf5a6'), 'title': 'Shield of Straw'},
#  {'_id': ObjectId('573a13dbf29313caabdaf845'), 'title': 'Revolution'},
#  {'_id': ObjectId('573a13dbf29313caabdb00fa'),
#   'title': 'Berserk: The Golden Age Arc III - The Advent'},
#  {'_id': ObjectId('573a13dbf29313caabdb010f'),
#   'title': 'Berserk: The Golden Age Arc II - The Battle for Doldrey'},
#  {'_id': ObjectId('573a13dcf29313caabdb0b8f'),
#   'title': 'Leaving on the 15th Spring'},
#  {'_id': ObjectId('573a13dcf29313caabdb0bda'), 'title': 'Cat Shit One'},
#  {'_id': ObjectId('573a13dcf29313caabdb13ec'), 'title': 'One Piece Film Z'},
#  {'_id': ObjectId('573a13dcf29313caabdb2258'), 'title': "It's Me, It's Me"},
#  {'_id': ObjectId('573a13dcf29313caabdb2c9d'),
#   'title': 'The Last Chance: Diary of Comedians'},
#  {'_id': ObjectId('573a13ddf29313caabdb317b'), 'title': 'The Eternal Zero'},
#  {'_id': ObjectId('573a13ddf29313caabdb3516'), 'title': 'Killers'},
#  {'_id': ObjectId('573a13ddf29313caabdb3528'),
#   'title': "Why Don't You Play in Hell?"},
#  {'_id': ObjectId('573a13ddf29313caabdb3c35'),
#   'title': 'Mardock Scramble: The Third Exhaust'},
#  {'_id': ObjectId('573a13ddf29313caabdb4ced'),
#   'title': 'Puella Magi Madoka Magica the Movie Part III: Rebellion'},
#  {'_id': ObjectId('573a13def29313caabdb6d85'), 'title': 'The Little House'},
#  {'_id': ObjectId('573a13def29313caabdb713f'), 'title': 'Miss Zombie'},
#  {'_id': ObjectId('573a13dff29313caabdb7c43'), 'title': "The Devil's Path"},
#  {'_id': ObjectId('573a13dff29313caabdb808a'), 'title': 'Hal'},
#  {'_id': ObjectId('573a13dff29313caabdb8284'),
#   'title': 'The Tale of The Princess Kaguya'},
#  {'_id': ObjectId('573a13dff29313caabdb89d2'), 'title': 'The Garden of Words'},
#  {'_id': ObjectId('573a13e0f29313caabdb9f6f'),
#   'title': 'Ghost in the Shell Arise: Border 1 - Ghost Pain'},
#  {'_id': ObjectId('573a13e0f29313caabdba876'),
#   'title': 'Iron Man: Rise of Technovore'},
#  {'_id': ObjectId('573a13e0f29313caabdbae7c'),
#   'title': 'Harlock: Space Pirate'},
#  {'_id': ObjectId('573a13e0f29313caabdbbae5'),
#   'title': 'HK: Forbidden Super Hero'},
#  {'_id': ObjectId('573a13e1f29313caabdbcd7c'), 'title': 'Kick-Heart'},
#  {'_id': ObjectId('573a13e1f29313caabdbd198'), 'title': 'My Man'},
#  {'_id': ObjectId('573a13e2f29313caabdbe4a7'), 'title': 'Tokyo Tribe'},
#  {'_id': ObjectId('573a13e2f29313caabdbe8fe'), 'title': 'Furious 7'},
#  {'_id': ObjectId('573a13e2f29313caabdbe940'),
#   'title': 'The Rise and Rise of Bitcoin'},
#  {'_id': ObjectId('573a13e2f29313caabdbf549'), 'title': 'A Touch of Sin'},
#  {'_id': ObjectId('573a13e3f29313caabdc0720'), 'title': 'Ilo Ilo'},
#  {'_id': ObjectId('573a13e3f29313caabdc0cd8'), 'title': 'R100'},
#  {'_id': ObjectId('573a13e3f29313caabdc0d76'), 'title': 'Over Your Dead Body'},
#  {'_id': ObjectId('573a13e4f29313caabdc11c8'), 'title': 'The ABCs of Death 2'},
#  {'_id': ObjectId('573a13e5f29313caabdc2878'), 'title': 'Wood Job!'},
#  {'_id': ObjectId('573a13e5f29313caabdc31d3'), 'title': 'Patema Inverted'},
#  {'_id': ObjectId('573a13e5f29313caabdc3897'), 'title': 'Homeland'},
#  {'_id': ObjectId('573a13e6f29313caabdc49d7'),
#   'title': 'Blue Exorcist: The Movie'},
#  {'_id': ObjectId('573a13e6f29313caabdc4a07'),
#   'title': 'Rurèni Kenshin: Densetsu no saigo-hen'},
#  {'_id': ObjectId('573a13e6f29313caabdc61f1'), 'title': "Say 'I Love You'"},
#  {'_id': ObjectId('573a13e6f29313caabdc66c4'),
#   'title': 'The Snow White Murder Case'},
#  {'_id': ObjectId('573a13e7f29313caabdc6da0'), 'title': 'The World of Kanako'},
#  {'_id': ObjectId('573a13e7f29313caabdc74b6'),
#   'title': "'Til Madness Do Us Part"},
#  {'_id': ObjectId('573a13e7f29313caabdc7f1d'), 'title': 'Gun Woman'},
#  {'_id': ObjectId('573a13e8f29313caabdc911a'), 'title': "Giovanni's Island"},
#  {'_id': ObjectId('573a13e8f29313caabdc9d89'),
#   'title': 'The Kingdom of Dreams and Madness'},
#  {'_id': ObjectId('573a13e8f29313caabdca142'), 'title': 'Neko no shukai'},
#  {'_id': ObjectId('573a13e8f29313caabdcaa94'), 'title': 'Still the Water'},
#  {'_id': ObjectId('573a13e8f29313caabdcaf3f'),
#   'title': 'Sword Art Online Extra Edition'},
#  {'_id': ObjectId('573a13e8f29313caabdcb5ae'), 'title': 'Hotori no sakuko'},
#  {'_id': ObjectId('573a13e9f29313caabdcbb9f'), 'title': 'Seventh Code'},
#  {'_id': ObjectId('573a13e9f29313caabdcc71a'), 'title': 'Samurai Hustle'},
#  {'_id': ObjectId('573a13e9f29313caabdcc71f'), 'title': 'Uzumasa Limelight'},
#  {'_id': ObjectId('573a13e9f29313caabdccddc'),
#   'title': 'Bayonetta: Bloody Fate'},
#  {'_id': ObjectId('573a13e9f29313caabdcd809'), 'title': 'Un altro mondo'},
#  {'_id': ObjectId('573a13e9f29313caabdcdb3d'),
#   'title': 'Stand by Me Doraemon'},
#  {'_id': ObjectId('573a13eaf29313caabdce2c2'), 'title': 'Parasyte: Part 1'},
#  {'_id': ObjectId('573a13eaf29313caabdce6a9'), 'title': 'As the Gods Will'},
#  {'_id': ObjectId('573a13eaf29313caabdcf802'), 'title': 'Short Peace'},
#  {'_id': ObjectId('573a13eaf29313caabdcfacf'),
#   'title': 'When Marnie Was There'},
#  {'_id': ObjectId('573a13ecf29313caabdd271a'),
#   'title': 'Avengers Confidential: Black Widow & Punisher'},
#  {'_id': ObjectId('573a13edf29313caabdd37bd'), 'title': 'Snow on the Blades'},
#  {'_id': ObjectId('573a13edf29313caabdd3f72'), 'title': 'Saihate nite'},
#  {'_id': ObjectId('573a13eef29313caabdd531d'), 'title': "Chasuke's Journey"},
#  {'_id': ObjectId('573a13eef29313caabdd5320'), 'title': 'Pale Moon'},
#  {'_id': ObjectId('573a13eff29313caabdd7495'),
#   'title': 'Animation Runner Kuromi 2'},
#  {'_id': ObjectId('573a13eff29313caabdd7ad9'), 'title': 'Appleseed Alpha'},
#  {'_id': ObjectId('573a13eff29313caabdd7dca'), 'title': 'Sworn Virgin'},
#  {'_id': ObjectId('573a13eff29313caabdd900f'), 'title': 'Miss Hokusai'},
#  {'_id': ObjectId('573a13f0f29313caabdda7ac'),
#   'title': 'Mountains May Depart'},
#  {'_id': ObjectId('573a13f0f29313caabddae55'), 'title': 'Our Little Sister'},
#  {'_id': ObjectId('573a13f2f29313caabddd905'),
#   'title': 'Assassination Classroom'},
#  {'_id': ObjectId('573a13f3f29313caabdde5ce'), 'title': 'Fires on the Plain'},
#  {'_id': ObjectId('573a13f3f29313caabdde93d'), 'title': 'The Birth of Sakè'},
#  {'_id': ObjectId('573a13f3f29313caabddf066'),
#   'title': 'Pokèmon the Movie: Diancie and the Cocoon of Destruction'},
#  {'_id': ObjectId('573a13f5f29313caabde3a5f'),
#   'title': 'Journey to the Shore'},
#  {'_id': ObjectId('573a13f5f29313caabde445e'), 'title': 'The Shaman'},
#  {'_id': ObjectId('573a13f6f29313caabde50df'),
#   'title': 'The Boy and the Beast'},
#  {'_id': ObjectId('573a13f6f29313caabde568a'), 'title': 'An'},
#  {'_id': ObjectId('573a13faf29313caabdec74f'), 'title': 'Babai'}]

# %%
# find one document in the "movies" collection - must have "Salma Hayek" in the "cast"
movies.find_one( { "cast": "Salma Hayek" } )
# Out:
# {'_id': ObjectId('573a1399f29313caabceea6d'),
#  'plot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'genres': ['Action', 'Drama'],
#  'runtime': 95,
#  'rated': 'R',
#  'cast': ['David Arquette', 'John Hawkes', 'Salma Hayek', 'Jason Wiles'],
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgwMzU3MDI1NF5BMl5BanBnXkFtZTcwMDUwMTIyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'title': 'Roadracers',
#  'fullplot': "Cynical look at a 50's rebellious Rocker who has to confront his future, thugs with knives, and the crooked town sheriff.",
#  'languages': ['English'],
#  'released': datetime.datetime(1994, 7, 22, 0, 0),
#  'directors': ['Robert Rodriguez'],
#  'writers': ['Robert Rodriguez', 'Tommy Nix'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-09-01 00:53:54.567000000',
#  'year': 1994,
#  'imdb': {'rating': 6.7, 'votes': 2036, 'id': 111002},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 7487, 'meter': 31},
#   'dvd': datetime.datetime(2002, 9, 3, 0, 0),
#   'critic': {'rating': 4.9, 'numReviews': 23, 'meter': 26},
#   'lastUpdated': datetime.datetime(2015, 9, 11, 18, 0, 30),
#   'rotten': 17,
#   'production': 'Hollywood Pictures',
#   'fresh': 6}}

# %%
# find all the documents in the "movies" collection with "Salma Hayek" in the "cast"
# this returns a cursor, which IS a Python iterable, but is NOT a document!
movies.find( { "cast": "Salma Hayek" } )

# %%
# return the count of movies with "Salma Hayek" in the "cast"
movies.find( { "cast": "Salma Hayek" } ).count()

# %%
# find all movies with Salma Hayek
# then pretty print
cursor = movies.find( { "cast": "Salma Hayek" } )
from bson.json_util import dumps
print(dumps(cursor, indent=2))

# %%
# find all movies with Salma Hayek, but only project the "_id" and "title" fields
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1 } )
print(dumps(cursor, indent=2))

# %%
# find all movies with Salma Hayek, but only project the "title" field
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1, "_id": 0 } )
print(dumps(cursor, indent=2))
